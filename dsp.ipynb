# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
n=int(input("enter number:"))
temp=n;
rev=0
while(n>0):
  dig=n%10
  rev=rev*10+dig
  n=n//10
if(temp==rev):
  print("the number is a palindrome!")
else:
  print("the number isn't a palindrome!")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# enter number:9
# the number is a palindrome!

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
num = 7

factorial = 1
if num < 0:
    print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
    print("The factorial of 0 is 1")
else:
    for i in range(1, num + 1):
        factorial *= i
    print(f"The factorial of {num} is {factorial}")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# The factorial of 7 is 5040

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
num = 29
flag = False

if num == 1:
    print(num, "is not a prime number")
elif num > 1:
    for i in range(2, num):
        if (num % i) == 0:
            flag = True
            break
    if flag:
        print(num, "is not a prime number")
    else:
        print(num, "is a prime number")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# 29 is a prime number

# %%
print("nitin johri")
print("1/22/fet/bcs/303")
class Factorial:
    def __init__(self, num):
        self.num = num

    def calculate(self):
        if self.num < 0:
            return "Sorry, factorial does not exist for negative numbers"
        elif self.num == 0:
            return 1
        else:
            factorial = 1
            for i in range(1, self.num + 1):
                factorial *= i
            return factorial
num = 7
fact = Factorial(num)
print(f"The factorial of {num} is {fact.calculate()}")
# Out:
# nitin johri
# 1/22/fet/bcs/303
# The factorial of 7 is 5040

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
single_quote_str = 'Hello, World!'
double_quote_str = "Python Programming"
triple_quote_str = '''This is a multi-line
string literal.'''
integer_literal = 42
float_literal = 3.14159
complex_literal = 1 + 2j
true_literal = True
false_literal = False
none_literal = None
list_literal = [1, 2, 3, 4, 5]
tuple_literal = (6, 7, 8, 9, 10)
dict_literal = {'name': 'Alice', 'age': 30}
set_literal = {11, 12, 13, 14, 15}
print("String Literals:")
print(single_quote_str)
print(double_quote_str)
print(triple_quote_str)

print("\nNumeric Literals:")
print("Integer:", integer_literal)
print("Float:", float_literal)
print("Complex:", complex_literal)

print("\nBoolean Literals:")
print("True:", true_literal)
print("False:", false_literal)

print("\nSpecial Literal:")
print("None:", none_literal)

print("\nLiteral Collections:")
print("List:", list_literal)
print("Tuple:", tuple_literal)
print("Dictionary:", dict_literal)
print("Set:", set_literal)
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# String Literals:
# Hello, World!
# Python Programming
# This is a multi-line
# string literal.
#
# Numeric Literals:
# Integer: 42
# Float: 3.14159
# Complex: (1+2j)
#
# Boolean Literals:
# True: True
# False: False
#
# Special Literal:
# None: None
#
# Literal Collections:
# List: [1, 2, 3, 4, 5]
# Tuple: (6, 7, 8, 9, 10)
# Dictionary: {'name': 'Alice', 'age': 30}
# Set: {11, 12, 13, 14, 15}

# %%
print("nitin johri")
print("1/22/fet/bcs/303")
result= 5+2*3**2
print(result)
# Out:
# nitin johri
# 1/22/fet/bcs/303
# 23

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
num=7
num1=2
num=num+num1
num1=num-num1
num=num-num1
print(num)
print(num1)
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# 2
# 7

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True
number = int(input("Enter a number: "))
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Enter a number: 2
# 2 is a prime number.

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
fruits = ["apple", "banana", "cherry", "date"]
print("apple" in fruits)
print("mango" in fruits)
print("apple" not in fruits)
print("mango" not in fruits)
if "banana" in fruits:
    print("Banana is in the list!")
if "grape" not in fruits:
    print("Grape is not in the list!")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# True
# False
# False
# True
# Banana is in the list!
# Grape is not in the list!

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
def determine_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'
score = float(input("Enter the student's score: "))
grade = determine_grade(score)
print(f"The student's grade is: {grade}")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Enter the student's score: 90
# The student's grade is: A

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
def get_day_name(day_number):
    if day_number == 1:
        return 'Monday'
    elif day_number == 2:
        return 'Tuesday'
    elif day_number == 3:
        return 'Wednesday'
    elif day_number == 4:
        return 'Thursday'
    elif day_number == 5:
        return 'Friday'
    elif day_number == 6:
        return 'Saturday'
    elif day_number == 7:
        return 'Sunday'
    else:
        return 'Invalid day number'
try:
    day_number = int(input("Enter the day number (1 for Monday, 2 for Tuesday, etc.): "))
    day_name = get_day_name(day_number)
    print(f"The day is: {day_name}")
except ValueError:
    print("Please enter a valid integer.")
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Enter the day number (1 for Monday, 2 for Tuesday, etc.): 4
# The day is: Thursday

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
class Employee:
    def __init__(self, name, employee_id, position):
        self.name = name
        self.employee_id = employee_id
        self.position = position

    def __str__(self):
        return f"ID: {self.employee_id}, Name: {self.name}, Position: {self.position}"

class EmployeeManagementSystem:
    def __init__(self):
        self.employees = {}

    def add_employee(self, name, employee_id, position):
        if employee_id in self.employees:
            print(f"Employee with ID {employee_id} already exists.")
        else:
            self.employees[employee_id] = Employee(name, employee_id, position)
            print(f"Employee {name} added successfully.")

    def remove_employee(self, employee_id):
        if employee_id in self.employees:
            removed_employee = self.employees.pop(employee_id)
            print(f"Employee {removed_employee.name} removed successfully.")
        else:
            print(f"Employee with ID {employee_id} does not exist.")

    def display_employee_details(self, employee_id):
        if employee_id in self.employees:
            print(self.employees[employee_id])
        else:
            print(f"Employee with ID {employee_id} does not exist.")

# Example usage
def main():
    system = EmployeeManagementSystem()

    while True:
        print("\nEmployee Management System")
        print("1. Add Employee")
        print("2. Remove Employee")
        print("3. Display Employee Details")
        print("4. Exit")

        choice = input("Enter your choice (1-4): ")

        if choice == '1':
            name = input("Enter employee name: ")
            employee_id = input("Enter employee ID: ")
            position = input("Enter employee position: ")
            system.add_employee(name, employee_id, position)

        elif choice == '2':
            employee_id = input("Enter employee ID to remove: ")
            system.remove_employee(employee_id)

        elif choice == '3':
            employee_id = input("Enter employee ID to display: ")
            system.display_employee_details(employee_id)

        elif choice == '4':
            print("Exiting the system.")
            break

        else:
            print("Invalid choice. Please enter a number between 1 and 4.")

if __name__ == "__main__":
    main()
# Out:
# Nitin johri
# 1/22/fet/bcs/303
#
# Employee Management System
# 1. Add Employee
# 2. Remove Employee
# 3. Display Employee Details
# 4. Exit
# Enter your choice (1-4): 1
# Enter employee name: nitin johri
# Enter employee ID: 667
# Enter employee position: HR
# Employee nitin johri added successfully.
#
# Employee Management System
# 1. Add Employee
# 2. Remove Employee
# 3. Display Employee Details
# 4. Exit
# Enter your choice (1-4): 3
# Enter employee ID to display: 667
# ID: 667, Name: nitin johri, Position: HR
#
# Employee Management System
# 1. Add Employee
# 2. Remove Employee
# 3. Display Employee Details
# 4. Exit
# Enter your choice (1-4): 2
# Enter employee ID to remove: 667
# Employee nitin johri removed successfully.
#
# Employee Management System
# 1. Add Employee
# 2. Remove Employee
# 3. Display Employee Details
# 4. Exit
# Enter your choice (1-4): 4
# Exiting the system.

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
def calculate(expression):
    try:
        result = eval(expression)
        return result
    except Exception as e:
        return f"Error: {e}"
def main():
    print("Simple Calculator")
    print("You can use operators +, -, *, / and parentheses () for calculations.")
    print("Type 'exit' to quit.")
    while True:
        expression = input("Enter expression: ")
        if expression.lower() == 'exit':
            print("Exiting the calculator.")
            break
        result = calculate(expression)
        print(f"Result: {result}")
if __name__ == "__main__":
    main()
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Simple Calculator
# You can use operators +, -, *, / and parentheses () for calculations.
# Type 'exit' to quit.
# Enter expression: 3+4
# Result: 7
# Enter expression: 6**5*5+23
# Result: 38903
# Enter expression: exit
# Exiting the calculator.

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
def calculate_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'
def main():
    try:
        score = float(input("Enter the student's score (0-100): "))

        if 0 <= score <= 100:
            grade = calculate_grade(score)
            print(f"The student's grade is: {grade}")
        else:
            print("Score must be between 0 and 100.")
    except ValueError:
        print("Invalid input. Please enter a numeric value.")

if __name__ == "__main__":
    main()
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Enter the student's score (0-100): 56
# The student's grade is: F

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
import random
def number_guessing_game():
    secret_number = random.randint(1, 100)
    attempts = 0
    max_attempts = 10
    print("Welcome to the Number Guessing Game!")
    print("I have selected a number between 1 and 100.")
    print(f"You have {max_attempts} attempts to guess it.")

    while attempts < max_attempts:
        try:
            guess = int(input("Enter your guess: "))
            if guess < 1 or guess > 100:
                print("Please enter a number between 1 and 100.")
                continue
            attempts += 1
            if guess < secret_number:
                print("Too low! Try again.")
            elif guess > secret_number:
                print("Too high! Try again.")
            else:
                print(f"Congratulations! You guessed the number {secret_number} correctly in {attempts} attempts.")
                break
        except ValueError:
            print("Invalid input. Please enter a numeric value.")
    if guess != secret_number:
        print(f"Sorry, you've used all your attempts. The correct number was {secret_number}.")
if __name__ == "__main__":
    number_guessing_game()
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Welcome to the Number Guessing Game!
# I have selected a number between 1 and 100.
# You have 10 attempts to guess it.
# Enter your guess: 45
# Too high! Try again.
# Enter your guess: 90
# Too high! Try again.
# Enter your guess: 32
# Too high! Try again.
# Enter your guess: 21
# Too high! Try again.
# Enter your guess: 1
# Too low! Try again.
# Enter your guess: 3
# Too low! Try again.
# Enter your guess: 10
# Too high! Try again.
# Enter your guess: 9
# Too high! Try again.
# Enter your guess: 7
# Congratulations! You guessed the number 7 correctly in 9 attempts.

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
num=int(input("Enter any Number : "))
max=0
while num>0:
    digit=num%10
    if max<digit:
        max=digit
    num=num//10
print("Largest Digit is : ",max)
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# Enter any Number : 3421
# Largest Digit is :  4

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
def getSum(n):
  sum = 0
  for digit in str(n):
    sum += int(digit)
    return sum

n = 12345
print(getSum(n))
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# 1

# %%
print("Nitin johri")
print("1/22/fet/bcs/303")
for fizzbuzz in range(51):
    if fizzbuzz % 3 == 0 and fizzbuzz % 5 == 0:
        print("fizzbuzz")
        continue
    elif fizzbuzz % 3 == 0:
        print("fizz")
        continue
    elif fizzbuzz % 5 == 0:
        print("buzz")
        continue
    print(fizzbuzz)
# Out:
# Nitin johri
# 1/22/fet/bcs/303
# fizzbuzz
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
